# %%
import pandas as pd
import sqlite3

# %%
# Explore dataset
# Playoff_df = pd.read_csv('2022-2023_NBA_Playoffs_Data_Clean.csv')
Regular_Season_df = pd.read_csv('2022-2023_NBA_Regular_Season_Data_Clean.csv')

# %%
# Playoff_df

# %%
Regular_Season_df
# Out:
#       Rk            Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...    FT%  \
# 0      1  Precious Achiuwa   C   23  TOR  55  12  20.7  3.6   7.3  ...  0.702
# 1      2      Steven Adams   C   29  MEM  42  42  27.0  3.7   6.3  ...  0.364
# 2      3       Bam Adebayo   C   25  MIA  75  75  34.6  8.0  14.9  ...  0.806
# 3      4      Ochai Agbaji  SG   22  UTA  59  22  20.5  2.8   6.5  ...  0.812
# 4      5      Santi Aldama  PF   22  MEM  77  20  21.8  3.2   6.8  ...  0.750
# ..   ...               ...  ..  ...  ...  ..  ..   ...  ...   ...  ...    ...
# 674  535    Thaddeus Young  PF   34  TOR  54   9  14.7  2.0   3.7  ...  0.692
# 675  536        Trae Young  PG   24  ATL  73  73  34.8  8.2  19.0  ...  0.886
# 676  537    Omer Yurtseven   C   24  MIA   9   0   9.2  1.8   3.0  ...  0.833
# 677  538       Cody Zeller   C   30  MIA  15   2  14.5  2.5   3.9  ...  0.686
# 678  539       Ivica Zubac   C   25  LAC  76  76  28.6  4.3   6.8  ...  0.697
#
# ...

# %%
Regular_Season_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 679 entries, 0 to 678
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rk            679 non-null    int64
#  1   Player        679 non-null    object
#  2   Pos           679 non-null    object
#  3   Age           679 non-null    int64
#  4   Tm            679 non-null    object
#  5   G             679 non-null    int64
#  6   GS            679 non-null    int64
#  7   MP            679 non-null    float64
#  8   FG            679 non-null    float64
#  9   FGA           679 non-null    float64
#  10  FG%           679 non-null    float64
#  11  3P            679 non-null    float64
#  12  3PA           679 non-null    float64
#  13  3P%           679 non-null    float64
#  14  2P            679 non-null    float64
#  15  2PA           679 non-null    float64
#  16  2P%           679 non-null    float64
#  17  EffectiveFG%  679 non-null    float64
# ...

# %%
# Playoff_df.info()

# %%
# players_PO = list(Playoff_df['Player'].unique())
# players_PO

# %%
players_RS =list(Regular_Season_df['Player'].unique())
players_RS
# Out:
# ['Precious Achiuwa',
#  'Steven Adams',
#  'Bam Adebayo',
#  'Ochai Agbaji',
#  'Santi Aldama',
#  'Nickeil Alexander-Walker',
#  'Grayson Allen',
#  'Jarrett Allen',
#  'Jose Alvarado',
#  'Kyle Anderson',
#  'Giannis Antetokounmpo',
#  'Thanasis Antetokounmpo',
#  'Cole Anthony',
#  'OG Anunoby',
#  'Ryan Arcidiacono',
#  'Deni Avdija',
#  'Deandre Ayton',
#  'Udoka Azubuike',
#  'Marvin Bagley III',
#  'Patrick Baldwin Jr.',
#  'LaMelo Ball',
#  'Mo Bamba',
#  'Paolo Banchero',
#  'Desmond Bane',
#  'Dalano Banton',
#  'Dominick Barlow',
#  'Harrison Barnes',
#  'Scottie Barnes',
#  'RJ Barrett',
#  'Will Barton',
#  'Charles Bassey',
#  'Keita Bates-Diop',
#  'Nicolas Batum',
#  'Darius Bazley',
#  'Bradley Beal',
#  'Malik Beasley',
#  'MarJon Beauchamp',
#  'D?vis Bert?ns',
#  'Patrick Beverley',
#  'Saddiq Bey',
#  'Khem Birch',
#  'Goga Bitadze',
#  'Bismack Biyombo',
#  'Buddy Boeheim',
#  'Bogdan Bogdanovi?',
#  'Bojan Bogdanovi?',
#  'Bol Bol',
#  'Leandro Bolmaro',
# ...

# %%
# players_PO = pd.DataFrame({
#     'Players_ID': [x + 1001 for x in range(len(players_PO))],
#     'Players': players_PO
# })

# %%
# players_PO

# %%
players_RS = pd.DataFrame({
    'Players_ID': [x + 1001 for x in range(len(players_RS))],
    'Players': players_RS
})

# %%
players_RS
# Out:
#      Players_ID           Players
# 0          1001  Precious Achiuwa
# 1          1002      Steven Adams
# 2          1003       Bam Adebayo
# 3          1004      Ochai Agbaji
# 4          1005      Santi Aldama
# ..          ...               ...
# 534        1535    Thaddeus Young
# 535        1536        Trae Young
# 536        1537    Omer Yurtseven
# 537        1538       Cody Zeller
# 538        1539       Ivica Zubac
#
# [539 rows x 2 columns]

# %%
players_RS.drop(columns=['Players_ID'])
# Out:
#               Players
# 0    Precious Achiuwa
# 1        Steven Adams
# 2         Bam Adebayo
# 3        Ochai Agbaji
# 4        Santi Aldama
# ..                ...
# 534    Thaddeus Young
# 535        Trae Young
# 536    Omer Yurtseven
# 537       Cody Zeller
# 538       Ivica Zubac
#
# [539 rows x 1 columns]

# %%
#Merge Regular Season
Players_RS_df = Regular_Season_df.merge(players_RS, left_on='Player', right_on='Players')

# %%
Players_RS_df = Players_RS_df[['Rk','Player','Pos','Age','Tm','G','GS','MP','FG','FGA','FT%','ORB','DRB','TRB','AST','STL','BLK','TOV','PF','PTS']]
Players_RS_df
# Out:
#       Rk            Player Pos  Age   Tm   G  GS    MP   FG   FGA    FT%  ORB  \
# 0      1  Precious Achiuwa   C   23  TOR  55  12  20.7  3.6   7.3  0.702  1.8
# 1      2      Steven Adams   C   29  MEM  42  42  27.0  3.7   6.3  0.364  5.1
# 2      3       Bam Adebayo   C   25  MIA  75  75  34.6  8.0  14.9  0.806  2.5
# 3      4      Ochai Agbaji  SG   22  UTA  59  22  20.5  2.8   6.5  0.812  0.7
# 4      5      Santi Aldama  PF   22  MEM  77  20  21.8  3.2   6.8  0.750  1.1
# ..   ...               ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...
# 674  535    Thaddeus Young  PF   34  TOR  54   9  14.7  2.0   3.7  0.692  1.3
# 675  536        Trae Young  PG   24  ATL  73  73  34.8  8.2  19.0  0.886  0.8
# 676  537    Omer Yurtseven   C   24  MIA   9   0   9.2  1.8   3.0  0.833  0.9
# 677  538       Cody Zeller   C   30  MIA  15   2  14.5  2.5   3.9  0.686  1.7
# 678  539       Ivica Zubac   C   25  LAC  76  76  28.6  4.3   6.8  0.697  3.1
#
# ...

# %%
# #MergePlayoff
# Players_PO_df = Playoff_df.merge(players_PO, left_on='Player', right_on='Players')

# %%
# Players_PO_df = Players_PO_df[['Players_ID','Rk','Player','Pos','Age','Tm','G','GS','MP','FG','FGA','FT%','ORB','DRB','TRB','AST','STL','BLK','TOV','PF','PTS']]
# Players_PO_df

# %%
# Export file as a CSV
Players_RS_df.to_csv("Data/Players_RS_df.csv", index=False, header=True)

# %%
# # Export file as a CSV
# Players_PO_df.to_csv("Data/Players_PO_df.csv", index=False, header=True)

# %%
#Connect to sqlite db
con = sqlite3.connect('2022-2023_Regular_Season.db')
cur = con.cursor()

# %%
cur.execute("drop table players_RS")

# %%
#Pandas for dataframe
# Regular_Season_df.to_sql('Player', con, index=False)
Players_RS_df.to_sql('Players_RS', con, index=False)
# Out:
# 679

# %%
#Run queries to test data
cur.execute("select * from Players_RS limit 10")
for row in cur:
    print(row)
# Out:
# (1, 'Precious Achiuwa', 'C', 23, 'TOR', 55, 12, 20.7, 3.6, 7.3, 0.702, 1.8, 4.1, 6.0, 0.9, 0.6, 0.5, 1.1, 1.9, 9.2)
# (2, 'Steven Adams', 'C', 29, 'MEM', 42, 42, 27.0, 3.7, 6.3, 0.364, 5.1, 6.5, 11.5, 2.3, 0.9, 1.1, 1.9, 2.3, 8.6)
# (3, 'Bam Adebayo', 'C', 25, 'MIA', 75, 75, 34.6, 8.0, 14.9, 0.806, 2.5, 6.7, 9.2, 3.2, 1.2, 0.8, 2.5, 2.8, 20.4)
# (4, 'Ochai Agbaji', 'SG', 22, 'UTA', 59, 22, 20.5, 2.8, 6.5, 0.812, 0.7, 1.3, 2.1, 1.1, 0.3, 0.3, 0.7, 1.7, 7.9)
# (5, 'Santi Aldama', 'PF', 22, 'MEM', 77, 20, 21.8, 3.2, 6.8, 0.75, 1.1, 3.7, 4.8, 1.3, 0.6, 0.6, 0.8, 1.9, 9.0)
# (6, 'Nickeil Alexander-Walker', 'SG', 24, 'TOT', 59, 3, 15.0, 2.2, 5.0, 0.667, 0.3, 1.5, 1.7, 1.8, 0.5, 0.4, 0.9, 1.5, 6.2)
# (6, 'Nickeil Alexander-Walker', 'SG', 24, 'UTA', 36, 3, 14.7, 2.3, 4.7, 0.692, 0.2, 1.4, 1.6, 2.1, 0.7, 0.4, 1.3, 1.6, 6.3)
# (6, 'Nickeil Alexander-Walker', 'SG', 24, 'MIN', 23, 0, 15.5, 2.1, 5.4, 0.619, 0.3, 1.5, 1.8, 1.4, 0.3, 0.3, 0.4, 1.3, 5.9)
# ...
